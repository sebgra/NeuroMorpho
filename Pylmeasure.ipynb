# %%
from pylmeasure import *

# %%
def get_measurment(neuron):
    
    features = dict()
    features['Surface'] = getOneMeasure('Surface',neuron)
    features['Soma_Surface'] = getOneMeasure('Soma_Surface',neuron)
    features['N_stems']= getOneMeasure('N_stems',neuron)
    features['N_bifs']= getOneMeasure('N_bifs',neuron)
    features['N_branch']= getOneMeasure('N_branch',neuron)
    features['N_tips']= getOneMeasure('N_tips',neuron)
    features['Width']= getOneMeasure('Width',neuron)
    features['Height']= getOneMeasure('Height',neuron)
    features['Depth']= getOneMeasure('Depth',neuron)
    features['Type']= getOneMeasure('Type',neuron)
    features['Diameter']= getOneMeasure('Diameter',neuron)
    features['Diameter_pow']= getOneMeasure('Diameter_pow',neuron)
    features['Length']= getOneMeasure('Length',neuron)
    features['Surface']= getOneMeasure('Surface',neuron)
    features['SectionArea']= getOneMeasure('SectionArea',neuron)
    features['Volume']= getOneMeasure('Volume',neuron)
    features['EucDistance']= getOneMeasure('EucDistance',neuron)
    features['PathDistance']= getOneMeasure('PathDistance',neuron)
    features['Branch_Order']= getOneMeasure('Branch_Order',neuron)
    features['Terminal_degree']= getOneMeasure('Terminal_degree',neuron)
    features['TerminalSegment']= getOneMeasure('TerminalSegment',neuron)
    features['Taper_1']= getOneMeasure('Taper_1',neuron)
    features['Taper_2']= getOneMeasure('Taper_2',neuron)
    features['Branch_pathlength']= getOneMeasure('Branch_pathlength',neuron)
    features['Contraction']= getOneMeasure('Contraction',neuron)
    features['Fragmentation']= getOneMeasure('Fragmentation',neuron)
    features['Daughter_Ratio']= getOneMeasure('Daughter_Ratio',neuron)
    features['Parent_Daughter_Ratio']= getOneMeasure('Parent_Daughter_Ratio',neuron)
    features['Partition_asymmetry']= getOneMeasure('Partition_asymmetry',neuron)
    features['Rall_Power']= getOneMeasure('Rall_Power',neuron)
    features['Pk']= getOneMeasure('Pk',neuron)
    features['Pk_classic']= getOneMeasure('Pk_classic',neuron)
    features['Pk_2']= getOneMeasure('Pk_2',neuron)
    features['Bif_ampl_local']= getOneMeasure('Bif_ampl_local',neuron)
    features['Bif_ampl_remote']= getOneMeasure('Bif_ampl_remote',neuron)
    features['Bif_tilt_local']= getOneMeasure('Bif_tilt_local',neuron)
    features['Bif_tilt_remote']= getOneMeasure('Bif_tilt_remote',neuron)
    features['Bif_torque_local']= getOneMeasure('Bif_torque_local',neuron)
    features['Bif_torque_remote']= getOneMeasure('Bif_torque_remote',neuron)
    features['Last_parent_diam']= getOneMeasure('Last_parent_diam',neuron)
    features['Diam_threshold']= getOneMeasure('Diam_threshold',neuron)
    features['HillmanThreshold']= getOneMeasure('HillmanThreshold',neuron)
    features['Helix']= getOneMeasure('Helix',neuron)
    features['Fractal_Dim']= getOneMeasure('Fractal_Dim',neuron)
    
    return features

# %%
os.chdir('/home/sebastien/Bureau/')

# %%
get_measurment('20131105-a1.CNG.swc')
# Out:
# {'Bif_ampl_local': {'Average': 95.4393,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 161.251,
#   'Minimum': 23.8271,
#   'StdDev': 42.9014,
#   'TotalSum': 2290.54},
#  'Bif_ampl_remote': {'Average': 81.4893,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 152.772,
#   'Minimum': 28.0837,
#   'StdDev': 33.2383,
#   'TotalSum': 1955.74},
#  'Bif_tilt_local': {'Average': 89.5394,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 146.511,
#   'Minimum': 24.0222,
#   'StdDev': 33.5633,
#   'TotalSum': 2148.95},
#  'Bif_tilt_remote': {'Average': 101.425,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 155.038,
#   'Minimum': 8.64536,
#   'StdDev': 35.9046,
#   'TotalSum': 2434.2},
#  'Bif_torque_local': {'Average': 96.3793,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 180.0,
#   'Minimum': 9.973,
#   'StdDev': 50.7658,
#   'TotalSum': 2313.1},
#  'Bif_torque_remote': {'Average': 98.1154,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 177.477,
#   'Minimum': 5.12306,
#   'StdDev': 56.7509,
#   'TotalSum': 2354.77},
#  'Branch_Order': {'Average': 3.60952,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 7.0,
#   'Minimum': 0.0,
#   'StdDev': 1.6568,
#   'TotalSum': 1137.0},
#  'Branch_pathlength': {'Average': 44.5598,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 207.81,
#   'Minimum': 2.49,
#   'StdDev': 42.4478,
#   'TotalSum': 2361.67},
#  'Contraction': {'Average': 0.911592,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.0,
#   'Minimum': 0.321845,
#   'StdDev': 0.111229,
#   'TotalSum': 48.3144},
#  'Daughter_Ratio': {'Average': 2.26245,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 6.58935,
#   'Minimum': 1.0,
#   'StdDev': 1.43754,
#   'TotalSum': 56.5613},
#  'Depth': {'Average': 37.99,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 37.99,
#   'Minimum': 37.99,
#   'StdDev': 0.0,
#   'TotalSum': 37.99},
#  'Diam_threshold': {'Average': 1.77152,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 6.54,
#   'Minimum': 0.332,
#   'StdDev': 1.3332,
#   'TotalSum': 51.374},
#  'Diameter': {'Average': 1.90537,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 6.54,
#   'Minimum': 0.332,
#   'StdDev': 1.03984,
#   'TotalSum': 600.19},
#  'Diameter_pow': {'Average': 2.90752,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 16.725,
#   'Minimum': 0.191297,
#   'StdDev': 2.57808,
#   'TotalSum': 915.87},
#  'EucDistance': {'Average': 78.793,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 195.489,
#   'Minimum': 0.0,
#   'StdDev': 41.7179,
#   'TotalSum': 24819.8},
#  'Fractal_Dim': {'Average': 1.03629,
#   'CompartmentsConsidered': 32.0,
#   'CompartmentsDiscarded': 283.0,
#   'Maximum': 1.28571,
#   'Minimum': 1.00183,
#   'StdDev': 0.0544327,
#   'TotalSum': 33.1613},
#  'Fragmentation': {'Average': 5.83333,
#   'CompartmentsConsidered': 54.0,
#   'CompartmentsDiscarded': 261.0,
#   'Maximum': 26.0,
#   'Minimum': 1.0,
#   'StdDev': 4.948,
#   'TotalSum': 315.0},
#  'Height': {'Average': 323.97,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 323.97,
#   'Minimum': 323.97,
#   'StdDev': 0.0,
#   'TotalSum': 323.97},
#  'Helix': {'Average': 0.00138158,
#   'CompartmentsConsidered': 304.0,
#   'CompartmentsDiscarded': 11.0,
#   'Maximum': 0.27,
#   'Minimum': -0.3,
#   'StdDev': 0.0574719,
#   'TotalSum': 0.42},
#  'HillmanThreshold': {'Average': 2.22034,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 6.54,
#   'Minimum': 0.56,
#   'StdDev': 1.33237,
#   'TotalSum': 64.39},
#  'Last_parent_diam': {'Average': 1.642,
#   'CompartmentsConsidered': 7.0,
#   'CompartmentsDiscarded': 308.0,
#   'Maximum': 2.322,
#   'Minimum': 0.686,
#   'StdDev': 0.499306,
#   'TotalSum': 11.494},
#  'Length': {'Average': 7.52214,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 28.8718,
#   'Minimum': 1.3568,
#   'StdDev': 3.9676,
#   'TotalSum': 2361.95},
#  'N_bifs': {'Average': 1.0,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 25.0},
#  'N_branch': {'Average': 1.0,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 53.0},
#  'N_stems': {'Average': 1.0,
#   'CompartmentsConsidered': 3.0,
#   'CompartmentsDiscarded': 312.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 3.0},
#  'N_tips': {'Average': 1.0,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 29.0},
#  'Parent_Daughter_Ratio': {'Average': 0.891901,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 3.70805,
#   'Minimum': 0.0957877,
#   'StdDev': 0.670154,
#   'TotalSum': 47.2708},
#  'Partition_asymmetry': {'Average': 0.6,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0,
#   'StdDev': 0.445304,
#   'TotalSum': 15.0},
#  'PathDistance': {'Average': 121.097,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 336.305,
#   'Minimum': 0.0,
#   'StdDev': 72.6527,
#   'TotalSum': 38145.6},
#  'Pk': {'Average': 2.43551,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 14.7382,
#   'Minimum': 0.28563,
#   'StdDev': 3.12983,
#   'TotalSum': 60.8878},
#  'Pk_2': {'Average': 2.62383,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 17.303,
#   'Minimum': 0.251441,
#   'StdDev': 3.69431,
#   'TotalSum': 65.5957},
#  'Pk_classic': {'Average': 2.0798,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 9.72845,
#   'Minimum': 0.403194,
#   'StdDev': 2.0171,
#   'TotalSum': 51.9949},
#  'Rall_Power': {'Average': 1.34389,
#   'CompartmentsConsidered': 9.0,
#   'CompartmentsDiscarded': 306.0,
#   'Maximum': 3.435,
#   'Minimum': 0.57,
#   'StdDev': 0.895681,
#   'TotalSum': 12.095},
#  'SectionArea': {'Average': 3.6312,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 33.5927,
#   'Minimum': 0.0865697,
#   'StdDev': 4.57848,
#   'TotalSum': 1140.2},
#  'Soma_Surface': {'Average': 69.6235,
#   'CompartmentsConsidered': 2.0,
#   'CompartmentsDiscarded': 313.0,
#   'Maximum': 71.3858,
#   'Minimum': 67.8613,
#   'StdDev': 1.76226,
#   'TotalSum': 139.247},
#  'Surface': {'Average': 44.6327,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 297.508,
#   'Minimum': 5.14058,
#   'StdDev': 34.3163,
#   'TotalSum': 14014.7},
#  'Taper_1': {'Average': 0.0540368,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.40964,
#   'Minimum': -1.1549,
#   'StdDev': 0.297085,
#   'TotalSum': 2.86395},
#  'Taper_2': {'Average': 0.0748895,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 0.892672,
#   'Minimum': -2.70805,
#   'StdDev': 0.612142,
#   'TotalSum': 3.96915},
#  'TerminalSegment': {'Average': 1.0,
#   'CompartmentsConsidered': 211.0,
#   'CompartmentsDiscarded': 104.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 211.0},
#  'Terminal_degree': {'Average': 1.92698,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 29.0,
#   'Minimum': 1.0,
#   'StdDev': 2.21851,
#   'TotalSum': 607.0},
#  'Type': {'Average': 2.6127,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 3.0,
#   'Minimum': 1.0,
#   'StdDev': 0.50039,
#   'TotalSum': 823.0},
#  'Volume': {'Average': 26.4561,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 248.639,
#   'Minimum': 0.490576,
#   'StdDev': 33.5281,
#   'TotalSum': 8307.22},
#  'Width': {'Average': 212.55,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 212.55,
#   'Minimum': 212.55,
#   'StdDev': 0.0,
#   'TotalSum': 212.55}}

# %%
features['Soma_Surface'] = getOneMeasure('Soma_Surface',neuron)
features['N_stems']= getOneMeasure('N_stems',neuron)
features['N_bifs']= getOneMeasure('N_bifs',neuron)
features['N_branch']= getOneMeasure('N_branch',neuron)
features['N_tips']= getOneMeasure('N_tips',neuron)
features['Width']= getOneMeasure('Width',neuron)
features['Height']= getOneMeasure('Height',neuron)
features['Depth']= getOneMeasure('Depth',neuron)
features['Type']= getOneMeasure('Type',neuron)
features['Diameter']= getOneMeasure('Diameter',neuron)
features['Diameter_pow']= getOneMeasure('Diameter_pow',neuron)
features['Length']= getOneMeasure('Length',neuron)
features['Surface']= getOneMeasure('Surface',neuron)
features['SectionArea']= getOneMeasure('SectionArea',neuron)
features['Volume']= getOneMeasure('Volume',neuron)
features['EucDistance']= getOneMeasure('EucDistance',neuron)
features['PathDistance']= getOneMeasure('PathDistance',neuron)
features['Branch_Order']= getOneMeasure('Branch_Order',neuron)
features['Terminal_degree']= getOneMeasure('Terminal_degree',neuron)
features['TerminalSegment']= getOneMeasure('TerminalSegment',neuron)
features['Taper_1']= getOneMeasure('Taper_1',neuron)
features['Taper_2']= getOneMeasure('Taper_2',neuron)
features['Branch_pathlength']= getOneMeasure('Branch_pathlength',neuron)
features['Contraction']= getOneMeasure('Contraction',neuron)
features['Fragmentation']= getOneMeasure('Fragmentation',neuron)
features['Daughter_Ratio']= getOneMeasure('Daughter_Ratio',neuron)
features['Parent_Daughter_Ratio']= getOneMeasure('Parent_Daughter_Ratio',neuron)
features['Partition_asymmetry']= getOneMeasure('Partition_asymmetry',neuron)
features['Rall_Power']= getOneMeasure('Rall_Power',neuron)
features['Pk']= getOneMeasure('Pk',neuron)
features['Pk_classic']= getOneMeasure('Pk_classic',neuron)
features['Pk_2']= getOneMeasure('Pk_2',neuron)
features['Bif_ampl_local']= getOneMeasure('Bif_ampl_local',neuron)
features['Bif_ampl_remote']= getOneMeasure('Bif_ampl_remote',neuron)
features['Bif_tilt_local']= getOneMeasure('Bif_tilt_local',neuron)
features['Bif_tilt_remote']= getOneMeasure('Bif_tilt_remote',neuron)
features['Bif_torque_local']= getOneMeasure('Bif_torque_local',neuron)
features['Bif_torque_remote']= getOneMeasure('Bif_torque_remote',neuron)
features['Last_parent_diam']= getOneMeasure('Last_parent_diam',neuron)
features['Diam_threshold']= getOneMeasure('Diam_threshold',neuron)
features['HillmanThreshold']= getOneMeasure('HillmanThreshold',neuron)
features['Helix']= getOneMeasure('Helix',neuron)
features['Fractal_Dim']= getOneMeasure('Fractal_Dim',neuron)

# %%
get_measurment('homo-12.CNG.swc')
# Out:
# {'Bif_ampl_local': {'Average': 71.756,
#   'CompartmentsConsidered': 206.0,
#   'CompartmentsDiscarded': 1447.0,
#   'Maximum': 176.765,
#   'Minimum': 8.87,
#   'StdDev': 33.88,
#   'TotalSum': 14781.7},
#  'Bif_ampl_remote': {'Average': 70.1649,
#   'CompartmentsConsidered': 206.0,
#   'CompartmentsDiscarded': 1447.0,
#   'Maximum': 169.423,
#   'Minimum': 0.071295,
#   'StdDev': 35.2713,
#   'TotalSum': 14454.0},
#  'Bif_tilt_local': {'Average': 114.49,
#   'CompartmentsConsidered': 206.0,
#   'CompartmentsDiscarded': 1447.0,
#   'Maximum': 167.322,
#   'Minimum': 21.3618,
#   'StdDev': 27.6152,
#   'TotalSum': 23584.9},
#  'Bif_tilt_remote': {'Average': 112.839,
#   'CompartmentsConsidered': 206.0,
#   'CompartmentsDiscarded': 1447.0,
#   'Maximum': 171.761,
#   'Minimum': 33.279,
#   'StdDev': 28.7164,
#   'TotalSum': 23244.9},
#  'Bif_torque_local': {'Average': 115.704,
#   'CompartmentsConsidered': 150.0,
#   'CompartmentsDiscarded': 1503.0,
#   'Maximum': 180.0,
#   'Minimum': 11.2302,
#   'StdDev': 58.3092,
#   'TotalSum': 17355.6},
#  'Bif_torque_remote': {'Average': 91.7738,
#   'CompartmentsConsidered': 195.0,
#   'CompartmentsDiscarded': 1458.0,
#   'Maximum': 180.0,
#   'Minimum': 2.63428,
#   'StdDev': 61.1848,
#   'TotalSum': 17895.9},
#  'Branch_Order': {'Average': 8.49728,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 20.0,
#   'Minimum': 0.0,
#   'StdDev': 5.08869,
#   'TotalSum': 14046.0},
#  'Branch_pathlength': {'Average': 12.5615,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 89.51,
#   'Minimum': 0.56,
#   'StdDev': 13.2462,
#   'TotalSum': 5338.63},
#  'Contraction': {'Average': 0.925012,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 1.0,
#   'Minimum': 0.312125,
#   'StdDev': 0.0887773,
#   'TotalSum': 393.13},
#  'Daughter_Ratio': {'Average': 1.00788,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 2.63158,
#   'Minimum': 1.0,
#   'StdDev': 0.110104,
#   'TotalSum': 208.632},
#  'Depth': {'Average': 46.9,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 46.9,
#   'Minimum': 46.9,
#   'StdDev': 0.0,
#   'TotalSum': 46.9},
#  'Diam_threshold': {'Average': 0.837973,
#   'CompartmentsConsidered': 219.0,
#   'CompartmentsDiscarded': 1434.0,
#   'Maximum': 11.648,
#   'Minimum': 0.17,
#   'StdDev': 0.962007,
#   'TotalSum': 183.516},
#  'Diameter': {'Average': 0.753396,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 11.648,
#   'Minimum': 0.17,
#   'StdDev': 0.500984,
#   'TotalSum': 1245.36},
#  'Diameter_pow': {'Average': 0.72846,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 39.7537,
#   'Minimum': 0.0700928,
#   'StdDev': 1.5724,
#   'TotalSum': 1204.14},
#  'EucDistance': {'Average': 75.6806,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 228.38,
#   'Minimum': 0.0,
#   'StdDev': 44.6647,
#   'TotalSum': 125100.0},
#  'Fractal_Dim': {'Average': 1.03334,
#   'CompartmentsConsidered': 163.0,
#   'CompartmentsDiscarded': 1490.0,
#   'Maximum': 1.29886,
#   'Minimum': 1.0,
#   'StdDev': 0.0427476,
#   'TotalSum': 168.434},
#  'Fragmentation': {'Average': 3.88028,
#   'CompartmentsConsidered': 426.0,
#   'CompartmentsDiscarded': 1227.0,
#   'Maximum': 18.0,
#   'Minimum': 1.0,
#   'StdDev': 2.97776,
#   'TotalSum': 1653.0},
#  'Height': {'Average': 314.71,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 314.71,
#   'Minimum': 314.71,
#   'StdDev': 0.0,
#   'TotalSum': 314.71},
#  'Helix': {'Average': -0.00136364,
#   'CompartmentsConsidered': 1628.0,
#   'CompartmentsDiscarded': 25.0,
#   'Maximum': 0.28,
#   'Minimum': -0.3,
#   'StdDev': 0.0716797,
#   'TotalSum': -2.22},
#  'HillmanThreshold': {'Average': 0.886594,
#   'CompartmentsConsidered': 219.0,
#   'CompartmentsDiscarded': 1434.0,
#   'Maximum': 11.648,
#   'Minimum': 0.17,
#   'StdDev': 1.09394,
#   'TotalSum': 194.164},
#  'Last_parent_diam': {'Average': 0.72,
#   'CompartmentsConsidered': 63.0,
#   'CompartmentsDiscarded': 1590.0,
#   'Maximum': 1.0,
#   'Minimum': 0.17,
#   'StdDev': 0.259898,
#   'TotalSum': 45.36},
#  'Length': {'Average': 3.23285,
#   'CompartmentsConsidered': 1652.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 17.6039,
#   'Minimum': 0.206155,
#   'StdDev': 2.02954,
#   'TotalSum': 5340.67},
#  'N_bifs': {'Average': 1.0,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 207.0},
#  'N_branch': {'Average': 1.0,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 425.0},
#  'N_stems': {'Average': 1.0,
#   'CompartmentsConsidered': 11.0,
#   'CompartmentsDiscarded': 1642.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 11.0},
#  'N_tips': {'Average': 1.0,
#   'CompartmentsConsidered': 219.0,
#   'CompartmentsDiscarded': 1434.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 219.0},
#  'Parent_Daughter_Ratio': {'Average': 0.97478,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0429258,
#   'StdDev': 0.146373,
#   'TotalSum': 414.281},
#  'Partition_asymmetry': {'Average': 0.55612,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0,
#   'StdDev': 0.44715,
#   'TotalSum': 115.117},
#  'PathDistance': {'Average': 112.225,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 254.623,
#   'Minimum': 0.0,
#   'StdDev': 65.0548,
#   'TotalSum': 185509.0},
#  'Pk': {'Average': 2.0,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 2.0,
#   'Minimum': 2.0,
#   'StdDev': 0.0,
#   'TotalSum': 414.0},
#  'Pk_2': {'Average': 1.99587,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 2.0,
#   'Minimum': 1.1444,
#   'StdDev': 0.0577387,
#   'TotalSum': 413.144},
#  'Pk_classic': {'Average': 1.9963,
#   'CompartmentsConsidered': 207.0,
#   'CompartmentsDiscarded': 1446.0,
#   'Maximum': 2.0,
#   'Minimum': 1.23425,
#   'StdDev': 0.0516754,
#   'TotalSum': 413.234},
#  'Rall_Power': {'Average': 0.0,
#   'CompartmentsConsidered': 0.0,
#   'CompartmentsDiscarded': 1653.0,
#   'Maximum': 0.0,
#   'Minimum': 0.0,
#   'StdDev': 0.0,
#   'TotalSum': 0.0},
#  'SectionArea': {'Average': 0.602916,
#   'CompartmentsConsidered': 1652.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 106.56,
#   'Minimum': 0.022698,
#   'StdDev': 3.29479,
#   'TotalSum': 996.017},
#  'Soma_Surface': {'Average': 212.394,
#   'CompartmentsConsidered': 2.0,
#   'CompartmentsDiscarded': 1651.0,
#   'Maximum': 212.572,
#   'Minimum': 212.216,
#   'StdDev': 0.177948,
#   'TotalSum': 424.788},
#  'Surface': {'Average': 7.92478,
#   'CompartmentsConsidered': 1652.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 212.572,
#   'Minimum': 0.323828,
#   'StdDev': 8.87881,
#   'TotalSum': 13091.7},
#  'Taper_1': {'Average': 0.0196894,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 1.53651,
#   'Minimum': 0.0,
#   'StdDev': 0.13203,
#   'TotalSum': 8.36801},
#  'Taper_2': {'Average': 0.0271731,
#   'CompartmentsConsidered': 425.0,
#   'CompartmentsDiscarded': 1228.0,
#   'Maximum': 0.957074,
#   'Minimum': 0.0,
#   'StdDev': 0.151472,
#   'TotalSum': 11.5486},
#  'TerminalSegment': {'Average': 1.0,
#   'CompartmentsConsidered': 766.0,
#   'CompartmentsDiscarded': 887.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 766.0},
#  'Terminal_degree': {'Average': 5.51906,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 219.0,
#   'Minimum': 1.0,
#   'StdDev': 12.7392,
#   'TotalSum': 9123.0},
#  'Type': {'Average': 2.47792,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 3.0,
#   'Minimum': 1.0,
#   'StdDev': 0.501785,
#   'TotalSum': 4096.0},
#  'Volume': {'Average': 2.37104,
#   'CompartmentsConsidered': 1652.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 619.01,
#   'Minimum': 0.0404785,
#   'StdDev': 19.1476,
#   'TotalSum': 3916.96},
#  'Width': {'Average': 277.68,
#   'CompartmentsConsidered': 1653.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 277.68,
#   'Minimum': 277.68,
#   'StdDev': 0.0,
#   'TotalSum': 277.68}}

# %% [markdown]
# # Saving dictionnaries

# %%
import glob
import os.path

# Basket Type

os.chdir('/Users/Sebastien/Desktop/plop/')

try : 
    os.mkdir('Basket_Lmeasurement_dictionnaries')
    
except : 
    pass

os.chdir('/Users/Sebastien/Desktop/plop/basket_ok/')

path = '/Users/Sebastien/Desktop/plop/Basket_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/basket_ok/*.swc')

for file in files:
    
    (filepath, filename) = os.path.split(file)
    #print(filename)
    name = filename[:-4]
    
    try : 
    
        tmp_var_dict = get_measurment(str(filename))
    
        np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    except : 
        print(filename,'is problematic')
        
# Motoneuron Type
        
os.chdir('/Users/Sebastien/Desktop/plop/')

try : 
    os.mkdir('Motoneuron_Lmeasurement_dictionnaries')
    
except : 
    pass

os.chdir('/Users/Sebastien/Desktop/plop/motoneuron_ok/')

path = '/Users/Sebastien/Desktop/plop/Motoneuron_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/motoneuron_ok/*.swc')

for file in files:
    
    (filepath, filename) = os.path.split(file)
    #print(filename)
    name = filename[:-4]
    
    try : 
    
        tmp_var_dict = get_measurment(str(filename))
    
        np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    except : 
        print(filename,'is problematic')
        

# Purkinje Type
        
os.chdir('/Users/Sebastien/Desktop/plop/')

try : 
    os.mkdir('Purkinje_Lmeasurement_dictionnaries')
    
except : 
    pass

os.chdir('/Users/Sebastien/Desktop/plop/purkinje_ok/')

path = '/Users/Sebastien/Desktop/plop/Purkinje_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/purkinje_ok/*.swc')

for file in files:
    
    (filepath, filename) = os.path.split(file)
    #print(filename)
    name = filename[:-4]
    
    try : 
    
        tmp_var_dict = get_measurment(str(filename))
    
        np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    except : 
        print(filename,'is problematic')
        
        
# Pyramidal Type
        
os.chdir('/Users/Sebastien/Desktop/plop/')

try : 
    os.mkdir('Pyramidal_Lmeasurement_dictionnaries')
    
except : 
    pass

os.chdir('/Users/Sebastien/Desktop/plop/pyramidal_ok/')

path = '/Users/Sebastien/Desktop/plop/Pyramidal_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/pyramidal_ok/*.swc')

for file in files:
    
    (filepath, filename) = os.path.split(file)
    #print(filename)
    name = filename[:-4]
    
    try : 
    
        tmp_var_dict = get_measurment(str(filename))
    
        np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    except : 
        print(filename,'is problematic')
        
        

# Retina Type
        
os.chdir('/Users/Sebastien/Desktop/plop/')

try : 
    os.mkdir('Retina_Lmeasurement_dictionnaries')
    
except : 
    pass

os.chdir('/Users/Sebastien/Desktop/plop/retina_ok/')

path = '/Users/Sebastien/Desktop/plop/Retina_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/retina_ok/*.swc')

for file in files:
    
    (filepath, filename) = os.path.split(file)
    #print(filename)
    name = filename[:-4]
    
    try : 
    
        tmp_var_dict = get_measurment(str(filename))
    
        np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    except : 
        print(filename,'is problematic')
# Out:
# AZ_Adult1_10CELLS-1.CNG.swc is problematic
# AZ_Adult1_10CELLS-10.CNG.swc is problematic
# AZ_Adult1_10CELLS-2.CNG.swc is problematic
# AZ_Adult1_10CELLS-3.CNG.swc is problematic
# AZ_Adult1_10CELLS-4.CNG.swc is problematic
# AZ_Adult1_10CELLS-5.CNG.swc is problematic
# AZ_Adult1_10CELLS-6.CNG.swc is problematic
# AZ_Adult1_10CELLS-7.CNG.swc is problematic
# AZ_Adult1_10CELLS-8.CNG.swc is problematic
# AZ_Adult1_10CELLS-9.CNG.swc is problematic
# AZ_Adult2_10CELLS-1.CNG.swc is problematic
# AZ_Adult2_10CELLS-10.CNG.swc is problematic
# AZ_Adult2_10CELLS-2.CNG.swc is problematic
# AZ_Adult2_10CELLS-3.CNG.swc is problematic
# AZ_Adult2_10CELLS-4.CNG.swc is problematic
# AZ_Adult2_10CELLS-5.CNG.swc is problematic
# AZ_Adult2_10CELLS-6.CNG.swc is problematic
# AZ_Adult2_10CELLS-7.CNG.swc is problematic
# AZ_Adult2_10CELLS-8.CNG.swc is problematic
# AZ_Adult2_10CELLS-9.CNG.swc is problematic
# AZ_Adult3_10CELLS-1.CNG.swc is problematic
# AZ_Adult3_10CELLS-10.CNG.swc is problematic
# AZ_Adult3_10CELLS-2.CNG.swc is problematic
# AZ_Adult3_10CELLS-3.CNG.swc is problematic
# AZ_Adult3_10CELLS-4.CNG.swc is problematic
# AZ_Adult3_10CELLS-5.CNG.swc is problematic
# AZ_Adult3_10CELLS-6.CNG.swc is problematic
# AZ_Adult3_10CELLS-7.CNG.swc is problematic
# AZ_Adult3_10CELLS-8.CNG.swc is problematic
# AZ_Adult3_10CELLS-9.CNG.swc is problematic
# AZ_Young1_10CELLS-1.CNG.swc is problematic
# AZ_Young1_10CELLS-10.CNG.swc is problematic
# AZ_Young1_10CELLS-2.CNG.swc is problematic
# AZ_Young1_10CELLS-3.CNG.swc is problematic
# AZ_Young1_10CELLS-4.CNG.swc is problematic
# AZ_Young1_10CELLS-5.CNG.swc is problematic
# AZ_Young1_10CELLS-6.CNG.swc is problematic
# AZ_Young1_10CELLS-7.CNG.swc is problematic
# AZ_Young1_10CELLS-8.CNG.swc is problematic
# AZ_Young1_10CELLS-9.CNG.swc is problematic
# AZ_Young2_10CELLS-1.CNG.swc is problematic
# AZ_Young2_10CELLS-10.CNG.swc is problematic
# AZ_Young2_10CELLS-2.CNG.swc is problematic
# AZ_Young2_10CELLS-3.CNG.swc is problematic
# AZ_Young2_10CELLS-4.CNG.swc is problematic
# AZ_Young2_10CELLS-5.CNG.swc is problematic
# AZ_Young2_10CELLS-6.CNG.swc is problematic
# AZ_Young2_10CELLS-7.CNG.swc is problematic
# AZ_Young2_10CELLS-8.CNG.swc is problematic
# AZ_Young2_10CELLS-9.CNG.swc is problematic
# AZ_Young3_10CELLS-1.CNG.swc is problematic
# AZ_Young3_10CELLS-10.CNG.swc is problematic
# AZ_Young3_10CELLS-2.CNG.swc is problematic
# AZ_Young3_10CELLS-3.CNG.swc is problematic
# AZ_Young3_10CELLS-4.CNG.swc is problematic
# AZ_Young3_10CELLS-5.CNG.swc is problematic
# AZ_Young3_10CELLS-6.CNG.swc is problematic
# AZ_Young3_10CELLS-7.CNG.swc is problematic
# AZ_Young3_10CELLS-8.CNG.swc is problematic
# AZ_Young3_10CELLS-9.CNG.swc is problematic
# PZ_Adult1-1.CNG.swc is problematic
# PZ_Adult1-10.CNG.swc is problematic
# PZ_Adult1-2.CNG.swc is problematic
# PZ_Adult1-3.CNG.swc is problematic
# PZ_Adult1-4.CNG.swc is problematic
# PZ_Adult1-5.CNG.swc is problematic
# PZ_Adult1-6.CNG.swc is problematic
# PZ_Adult1-7.CNG.swc is problematic
# PZ_Adult1-8.CNG.swc is problematic
# PZ_Adult1-9.CNG.swc is problematic
# PZ_Adult2-1.CNG.swc is problematic
# PZ_Adult2-10.CNG.swc is problematic
# PZ_Adult2-2.CNG.swc is problematic
# PZ_Adult2-3.CNG.swc is problematic
# PZ_Adult2-4.CNG.swc is problematic
# PZ_Adult2-5.CNG.swc is problematic
# PZ_Adult2-6.CNG.swc is problematic
# PZ_Adult2-7.CNG.swc is problematic
# PZ_Adult2-8.CNG.swc is problematic
# PZ_Adult2-9.CNG.swc is problematic
# PZ_Adult3-1.CNG.swc is problematic
# PZ_Adult3-10.CNG.swc is problematic
# PZ_Adult3-2.CNG.swc is problematic
# PZ_Adult3-3.CNG.swc is problematic
# PZ_Adult3-4.CNG.swc is problematic
# PZ_Adult3-5.CNG.swc is problematic
# PZ_Adult3-6.CNG.swc is problematic
# PZ_Adult3-7.CNG.swc is problematic
# PZ_Adult3-8.CNG.swc is problematic
# PZ_Adult3-9.CNG.swc is problematic
# PZ_Young1-1.CNG.swc is problematic
# PZ_Young1-10.CNG.swc is problematic
# PZ_Young1-2.CNG.swc is problematic
# PZ_Young1-3.CNG.swc is problematic
# PZ_Young1-4.CNG.swc is problematic
# PZ_Young1-5.CNG.swc is problematic
# PZ_Young1-6.CNG.swc is problematic
# PZ_Young1-7.CNG.swc is problematic
# PZ_Young1-8.CNG.swc is problematic
# PZ_Young1-9.CNG.swc is problematic
# PZ_Young2-1.CNG.swc is problematic
# PZ_Young2-10.CNG.swc is problematic
# PZ_Young2-2.CNG.swc is problematic
# PZ_Young2-3.CNG.swc is problematic
# PZ_Young2-4.CNG.swc is problematic
# PZ_Young2-5.CNG.swc is problematic
# PZ_Young2-6.CNG.swc is problematic
# PZ_Young2-7.CNG.swc is problematic
# PZ_Young2-8.CNG.swc is problematic
# PZ_Young2-9.CNG.swc is problematic
# PZ_Young3-1.CNG.swc is problematic
# PZ_Young3-10.CNG.swc is problematic
# PZ_Young3-2.CNG.swc is problematic
# PZ_Young3-3.CNG.swc is problematic
# PZ_Young3-4.CNG.swc is problematic
# PZ_Young3-5.CNG.swc is problematic
# PZ_Young3-6.CNG.swc is problematic
# PZ_Young3-7.CNG.swc is problematic
# PZ_Young3-8.CNG.swc is problematic
# PZ_Young3-9.CNG.swc is problematic
# 20150916-LPS22-1.CNG.swc is problematic
# 20160504-P21-control13-1.CNG.swc is problematic
# 20160506-P21-control20-1.CNG.swc is problematic
# 20160506-P21-control36-1.CNG.swc is problematic
# 20160506-P21-LPS51-1.CNG.swc is problematic
# 20160506-P21-LPS55-1.CNG.swc is problematic

# %%
get_measurment('/Users/Sebastien/Desktop/plop/purkinje_ok/AZ_Adult1_10CELLS-1.CNG.swc')
# Out:
# {'Bif_ampl_local': {'Average': 74.7121,
#   'CompartmentsConsidered': 106.0,
#   'CompartmentsDiscarded': 612.0,
#   'Maximum': 178.718,
#   'Minimum': 8.56439,
#   'StdDev': 27.3642,
#   'TotalSum': 7919.49},
#  'Bif_ampl_remote': {'Average': 62.8367,
#   'CompartmentsConsidered': 106.0,
#   'CompartmentsDiscarded': 612.0,
#   'Maximum': 178.718,
#   'Minimum': 4.55663,
#   'StdDev': 31.6596,
#   'TotalSum': 6660.69},
#  'Bif_tilt_local': {'Average': 118.92,
#   'CompartmentsConsidered': 106.0,
#   'CompartmentsDiscarded': 612.0,
#   'Maximum': 173.092,
#   'Minimum': 2.35046,
#   'StdDev': 31.1829,
#   'TotalSum': 12605.6},
#  'Bif_tilt_remote': {'Average': 129.833,
#   'CompartmentsConsidered': 106.0,
#   'CompartmentsDiscarded': 612.0,
#   'Maximum': 168.454,
#   'Minimum': 2.35046,
#   'StdDev': 24.4295,
#   'TotalSum': 13762.3},
#  'Bif_torque_local': {'Average': 84.8272,
#   'CompartmentsConsidered': 100.0,
#   'CompartmentsDiscarded': 618.0,
#   'Maximum': 180.0,
#   'Minimum': 2.66479,
#   'StdDev': 72.8083,
#   'TotalSum': 8482.72},
#  'Bif_torque_remote': {'Average': 81.4736,
#   'CompartmentsConsidered': 103.0,
#   'CompartmentsDiscarded': 615.0,
#   'Maximum': 180.0,
#   'Minimum': 0.506949,
#   'StdDev': 78.3016,
#   'TotalSum': 8391.78},
#  'Branch_Order': {'Average': 9.35933,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 18.0,
#   'Minimum': 0.0,
#   'StdDev': 3.63974,
#   'TotalSum': 6720.0},
#  'Branch_pathlength': {'Average': 8.43626,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 41.32,
#   'Minimum': 0.58,
#   'StdDev': 5.969,
#   'TotalSum': 1805.36},
#  'Contraction': {'Average': 0.960111,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0922294,
#   'StdDev': 0.0675544,
#   'TotalSum': 205.464},
#  'Daughter_Ratio': {'Average': 1.83546,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 10.64,
#   'Minimum': 1.0,
#   'StdDev': 1.34623,
#   'TotalSum': 196.395},
#  'Depth': {'Average': 8.75,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 8.75,
#   'Minimum': 8.75,
#   'StdDev': 0.0,
#   'TotalSum': 8.75},
#  'Diam_threshold': {'Average': 0.632413,
#   'CompartmentsConsidered': 108.0,
#   'CompartmentsDiscarded': 610.0,
#   'Maximum': 16.8106,
#   'Minimum': 0.13,
#   'StdDev': 1.32359,
#   'TotalSum': 68.3006},
#  'Diameter': {'Average': 0.952874,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 16.9374,
#   'Minimum': 0.13,
#   'StdDev': 1.97434,
#   'TotalSum': 684.163},
#  'Diameter_pow': {'Average': 1.73801,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 69.706,
#   'Minimum': 0.0468722,
#   'StdDev': 7.89241,
#   'TotalSum': 1247.89},
#  'EucDistance': {'Average': 109.083,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 180.134,
#   'Minimum': 0.0,
#   'StdDev': 43.7204,
#   'TotalSum': 78321.6},
#  'Fractal_Dim': {'Average': 1.01334,
#   'CompartmentsConsidered': 78.0,
#   'CompartmentsDiscarded': 640.0,
#   'Maximum': 1.18419,
#   'Minimum': 1.0,
#   'StdDev': 0.0234941,
#   'TotalSum': 79.0402},
#  'Fragmentation': {'Average': 3.33953,
#   'CompartmentsConsidered': 215.0,
#   'CompartmentsDiscarded': 503.0,
#   'Maximum': 16.0,
#   'Minimum': 1.0,
#   'StdDev': 2.27465,
#   'TotalSum': 718.0},
#  'Height': {'Average': 166.89,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 166.89,
#   'Minimum': 166.89,
#   'StdDev': 0.0,
#   'TotalSum': 166.89},
#  'Helix': {'Average': -0.000687237,
#   'CompartmentsConsidered': 713.0,
#   'CompartmentsDiscarded': 5.0,
#   'Maximum': 0.29,
#   'Minimum': -0.27,
#   'StdDev': 0.0400512,
#   'TotalSum': -0.49},
#  'HillmanThreshold': {'Average': 0.694028,
#   'CompartmentsConsidered': 108.0,
#   'CompartmentsDiscarded': 610.0,
#   'Maximum': 16.455,
#   'Minimum': 0.25,
#   'StdDev': 1.28621,
#   'TotalSum': 74.955},
#  'Last_parent_diam': {'Average': 0.564865,
#   'CompartmentsConsidered': 37.0,
#   'CompartmentsDiscarded': 681.0,
#   'Maximum': 1.77,
#   'Minimum': 0.25,
#   'StdDev': 0.290033,
#   'TotalSum': 20.9},
#  'Length': {'Average': 2.5194,
#   'CompartmentsConsidered': 717.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 11.0928,
#   'Minimum': 0.114018,
#   'StdDev': 1.25141,
#   'TotalSum': 1806.41},
#  'N_bifs': {'Average': 1.0,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 107.0},
#  'N_branch': {'Average': 1.0,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 214.0},
#  'N_stems': {'Average': 1.0,
#   'CompartmentsConsidered': 1.0,
#   'CompartmentsDiscarded': 717.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 1.0},
#  'N_tips': {'Average': 1.0,
#   'CompartmentsConsidered': 108.0,
#   'CompartmentsDiscarded': 610.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 108.0},
#  'Parent_Daughter_Ratio': {'Average': 0.786507,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 1.7451,
#   'Minimum': 0.093985,
#   'StdDev': 0.298829,
#   'TotalSum': 168.313},
#  'Partition_asymmetry': {'Average': 0.484973,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0,
#   'StdDev': 0.439709,
#   'TotalSum': 51.8921},
#  'PathDistance': {'Average': 123.546,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 196.844,
#   'Minimum': 0.0,
#   'StdDev': 43.0927,
#   'TotalSum': 88705.8},
#  'Pk': {'Average': 1.44995,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 5.15221,
#   'Minimum': 0.276312,
#   'StdDev': 0.674621,
#   'TotalSum': 155.144},
#  'Pk_2': {'Average': 1.42055,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 6.09073,
#   'Minimum': 0.20005,
#   'StdDev': 0.770397,
#   'TotalSum': 151.999},
#  'Pk_classic': {'Average': 1.47628,
#   'CompartmentsConsidered': 107.0,
#   'CompartmentsDiscarded': 611.0,
#   'Maximum': 4.61062,
#   'Minimum': 0.343712,
#   'StdDev': 0.614791,
#   'TotalSum': 157.962},
#  'Rall_Power': {'Average': 1.48597,
#   'CompartmentsConsidered': 36.0,
#   'CompartmentsDiscarded': 682.0,
#   'Maximum': 4.39,
#   'Minimum': 0.57,
#   'StdDev': 0.839555,
#   'TotalSum': 53.495},
#  'SectionArea': {'Average': 3.60673,
#   'CompartmentsConsidered': 717.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 225.312,
#   'Minimum': 0.0132732,
#   'StdDev': 23.6785,
#   'TotalSum': 2586.02},
#  'Soma_Surface': {'Average': 47.983,
#   'CompartmentsConsidered': 11.0,
#   'CompartmentsDiscarded': 707.0,
#   'Maximum': 145.975,
#   'Minimum': 12.199,
#   'StdDev': 33.7742,
#   'TotalSum': 527.813},
#  'Surface': {'Average': 6.57922,
#   'CompartmentsConsidered': 717.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 153.847,
#   'Minimum': 0.290465,
#   'StdDev': 9.88433,
#   'TotalSum': 4717.3},
#  'Taper_1': {'Average': 0.0446859,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 0.754967,
#   'Minimum': -0.107759,
#   'StdDev': 0.0981276,
#   'TotalSum': 9.56277},
#  'Taper_2': {'Average': 0.22106,
#   'CompartmentsConsidered': 214.0,
#   'CompartmentsDiscarded': 504.0,
#   'Maximum': 0.906015,
#   'Minimum': -1.34211,
#   'StdDev': 0.336381,
#   'TotalSum': 47.3068},
#  'TerminalSegment': {'Average': 1.0,
#   'CompartmentsConsidered': 381.0,
#   'CompartmentsDiscarded': 337.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 381.0},
#  'Terminal_degree': {'Average': 5.89694,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 108.0,
#   'Minimum': 1.0,
#   'StdDev': 14.1011,
#   'TotalSum': 4234.0},
#  'Type': {'Average': 2.96657,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 3.0,
#   'Minimum': 1.0,
#   'StdDev': 0.251228,
#   'TotalSum': 2130.0},
#  'Volume': {'Average': 4.69037,
#   'CompartmentsConsidered': 717.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 613.519,
#   'Minimum': 0.00968218,
#   'StdDev': 28.6321,
#   'TotalSum': 3363.0},
#  'Width': {'Average': 95.31,
#   'CompartmentsConsidered': 718.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 95.31,
#   'Minimum': 95.31,
#   'StdDev': 0.0,
#   'TotalSum': 95.31}}

# %%
read_dictionary = np.load('A.npy',allow_pickle='TRUE').item()

# %%
read_dictionary
# Out:
# {'Bif_ampl_local': {'Average': 95.4393,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 161.251,
#   'Minimum': 23.8271,
#   'StdDev': 42.9014,
#   'TotalSum': 2290.54},
#  'Bif_ampl_remote': {'Average': 81.4893,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 152.772,
#   'Minimum': 28.0837,
#   'StdDev': 33.2383,
#   'TotalSum': 1955.74},
#  'Bif_tilt_local': {'Average': 89.5394,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 146.511,
#   'Minimum': 24.0222,
#   'StdDev': 33.5633,
#   'TotalSum': 2148.95},
#  'Bif_tilt_remote': {'Average': 101.425,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 155.038,
#   'Minimum': 8.64536,
#   'StdDev': 35.9046,
#   'TotalSum': 2434.2},
#  'Bif_torque_local': {'Average': 96.3793,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 180.0,
#   'Minimum': 9.973,
#   'StdDev': 50.7658,
#   'TotalSum': 2313.1},
#  'Bif_torque_remote': {'Average': 98.1154,
#   'CompartmentsConsidered': 24.0,
#   'CompartmentsDiscarded': 291.0,
#   'Maximum': 177.477,
#   'Minimum': 5.12306,
#   'StdDev': 56.7509,
#   'TotalSum': 2354.77},
#  'Branch_Order': {'Average': 3.60952,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 7.0,
#   'Minimum': 0.0,
#   'StdDev': 1.6568,
#   'TotalSum': 1137.0},
#  'Branch_pathlength': {'Average': 44.5598,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 207.81,
#   'Minimum': 2.49,
#   'StdDev': 42.4478,
#   'TotalSum': 2361.67},
#  'Contraction': {'Average': 0.911592,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.0,
#   'Minimum': 0.321845,
#   'StdDev': 0.111229,
#   'TotalSum': 48.3144},
#  'Daughter_Ratio': {'Average': 2.26245,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 6.58935,
#   'Minimum': 1.0,
#   'StdDev': 1.43754,
#   'TotalSum': 56.5613},
#  'Depth': {'Average': 37.99,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 37.99,
#   'Minimum': 37.99,
#   'StdDev': 0.0,
#   'TotalSum': 37.99},
#  'Diam_threshold': {'Average': 1.77152,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 6.54,
#   'Minimum': 0.332,
#   'StdDev': 1.3332,
#   'TotalSum': 51.374},
#  'Diameter': {'Average': 1.90537,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 6.54,
#   'Minimum': 0.332,
#   'StdDev': 1.03984,
#   'TotalSum': 600.19},
#  'Diameter_pow': {'Average': 2.90752,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 16.725,
#   'Minimum': 0.191297,
#   'StdDev': 2.57808,
#   'TotalSum': 915.87},
#  'EucDistance': {'Average': 78.793,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 195.489,
#   'Minimum': 0.0,
#   'StdDev': 41.7179,
#   'TotalSum': 24819.8},
#  'Fractal_Dim': {'Average': 1.03629,
#   'CompartmentsConsidered': 32.0,
#   'CompartmentsDiscarded': 283.0,
#   'Maximum': 1.28571,
#   'Minimum': 1.00183,
#   'StdDev': 0.0544327,
#   'TotalSum': 33.1613},
#  'Fragmentation': {'Average': 5.83333,
#   'CompartmentsConsidered': 54.0,
#   'CompartmentsDiscarded': 261.0,
#   'Maximum': 26.0,
#   'Minimum': 1.0,
#   'StdDev': 4.948,
#   'TotalSum': 315.0},
#  'Height': {'Average': 323.97,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 323.97,
#   'Minimum': 323.97,
#   'StdDev': 0.0,
#   'TotalSum': 323.97},
#  'Helix': {'Average': 0.00138158,
#   'CompartmentsConsidered': 304.0,
#   'CompartmentsDiscarded': 11.0,
#   'Maximum': 0.27,
#   'Minimum': -0.3,
#   'StdDev': 0.0574719,
#   'TotalSum': 0.42},
#  'HillmanThreshold': {'Average': 2.22034,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 6.54,
#   'Minimum': 0.56,
#   'StdDev': 1.33237,
#   'TotalSum': 64.39},
#  'Last_parent_diam': {'Average': 1.642,
#   'CompartmentsConsidered': 7.0,
#   'CompartmentsDiscarded': 308.0,
#   'Maximum': 2.322,
#   'Minimum': 0.686,
#   'StdDev': 0.499306,
#   'TotalSum': 11.494},
#  'Length': {'Average': 7.52214,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 28.8718,
#   'Minimum': 1.3568,
#   'StdDev': 3.9676,
#   'TotalSum': 2361.95},
#  'N_bifs': {'Average': 1.0,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 25.0},
#  'N_branch': {'Average': 1.0,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 53.0},
#  'N_stems': {'Average': 1.0,
#   'CompartmentsConsidered': 3.0,
#   'CompartmentsDiscarded': 312.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 3.0},
#  'N_tips': {'Average': 1.0,
#   'CompartmentsConsidered': 29.0,
#   'CompartmentsDiscarded': 286.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 29.0},
#  'Parent_Daughter_Ratio': {'Average': 0.891901,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 3.70805,
#   'Minimum': 0.0957877,
#   'StdDev': 0.670154,
#   'TotalSum': 47.2708},
#  'Partition_asymmetry': {'Average': 0.6,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 1.0,
#   'Minimum': 0.0,
#   'StdDev': 0.445304,
#   'TotalSum': 15.0},
#  'PathDistance': {'Average': 121.097,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 336.305,
#   'Minimum': 0.0,
#   'StdDev': 72.6527,
#   'TotalSum': 38145.6},
#  'Pk': {'Average': 2.43551,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 14.7382,
#   'Minimum': 0.28563,
#   'StdDev': 3.12983,
#   'TotalSum': 60.8878},
#  'Pk_2': {'Average': 2.62383,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 17.303,
#   'Minimum': 0.251441,
#   'StdDev': 3.69431,
#   'TotalSum': 65.5957},
#  'Pk_classic': {'Average': 2.0798,
#   'CompartmentsConsidered': 25.0,
#   'CompartmentsDiscarded': 290.0,
#   'Maximum': 9.72845,
#   'Minimum': 0.403194,
#   'StdDev': 2.0171,
#   'TotalSum': 51.9949},
#  'Rall_Power': {'Average': 1.34389,
#   'CompartmentsConsidered': 9.0,
#   'CompartmentsDiscarded': 306.0,
#   'Maximum': 3.435,
#   'Minimum': 0.57,
#   'StdDev': 0.895681,
#   'TotalSum': 12.095},
#  'SectionArea': {'Average': 3.6312,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 33.5927,
#   'Minimum': 0.0865697,
#   'StdDev': 4.57848,
#   'TotalSum': 1140.2},
#  'Soma_Surface': {'Average': 69.6235,
#   'CompartmentsConsidered': 2.0,
#   'CompartmentsDiscarded': 313.0,
#   'Maximum': 71.3858,
#   'Minimum': 67.8613,
#   'StdDev': 1.76226,
#   'TotalSum': 139.247},
#  'Surface': {'Average': 44.6327,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 297.508,
#   'Minimum': 5.14058,
#   'StdDev': 34.3163,
#   'TotalSum': 14014.7},
#  'Taper_1': {'Average': 0.0540368,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 1.40964,
#   'Minimum': -1.1549,
#   'StdDev': 0.297085,
#   'TotalSum': 2.86395},
#  'Taper_2': {'Average': 0.0748895,
#   'CompartmentsConsidered': 53.0,
#   'CompartmentsDiscarded': 262.0,
#   'Maximum': 0.892672,
#   'Minimum': -2.70805,
#   'StdDev': 0.612142,
#   'TotalSum': 3.96915},
#  'TerminalSegment': {'Average': 1.0,
#   'CompartmentsConsidered': 211.0,
#   'CompartmentsDiscarded': 104.0,
#   'Maximum': 1.0,
#   'Minimum': 1.0,
#   'StdDev': 0.0,
#   'TotalSum': 211.0},
#  'Terminal_degree': {'Average': 1.92698,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 29.0,
#   'Minimum': 1.0,
#   'StdDev': 2.21851,
#   'TotalSum': 607.0},
#  'Type': {'Average': 2.6127,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 3.0,
#   'Minimum': 1.0,
#   'StdDev': 0.50039,
#   'TotalSum': 823.0},
#  'Volume': {'Average': 26.4561,
#   'CompartmentsConsidered': 314.0,
#   'CompartmentsDiscarded': 1.0,
#   'Maximum': 248.639,
#   'Minimum': 0.490576,
#   'StdDev': 33.5281,
#   'TotalSum': 8307.22},
#  'Width': {'Average': 212.55,
#   'CompartmentsConsidered': 315.0,
#   'CompartmentsDiscarded': 0.0,
#   'Maximum': 212.55,
#   'Minimum': 212.55,
#   'StdDev': 0.0,
#   'TotalSum': 212.55}}

# %%
import glob

#os.chdir('/Users/Sebastien/Desktop/plop/')

#try : 
#    os.mkdir('Purkinje_Lmeasurement_dictionnaries')
    
#except : 
#    pass

os.chdir('/Users/Sebastien/Desktop/plop/purkinje_ok/')

path = '/Users/Sebastien/Desktop/plop/Purkinje_Lmeasurement_dictionnaries/'
files = glob.glob('/Users/Sebastien/Desktop/plop/purkinje_ok/*.swc')
print(len(files))

for file in files:
    
    (filepath, filename) = os.path.split(file)
    print(filename)
    name = filename[:-4]
    
    #try : 
    
    tmp_var_dict = get_measurment(str(filename))
    
    np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
    
    #except : 
     #   print(filename,'is problematic')
# Out:
# 120
# AZ_Adult1_10CELLS-1.CNG.swc
# AZ_Adult1_10CELLS-10.CNG.swc
# AZ_Adult1_10CELLS-2.CNG.swc
# AZ_Adult1_10CELLS-3.CNG.swc
# AZ_Adult1_10CELLS-4.CNG.swc
# AZ_Adult1_10CELLS-5.CNG.swc
# AZ_Adult1_10CELLS-6.CNG.swc
# AZ_Adult1_10CELLS-7.CNG.swc
# AZ_Adult1_10CELLS-8.CNG.swc
# AZ_Adult1_10CELLS-9.CNG.swc
# AZ_Adult2_10CELLS-1.CNG.swc
# AZ_Adult2_10CELLS-10.CNG.swc
# AZ_Adult2_10CELLS-2.CNG.swc
# AZ_Adult2_10CELLS-3.CNG.swc
# AZ_Adult2_10CELLS-4.CNG.swc
# AZ_Adult2_10CELLS-5.CNG.swc
# AZ_Adult2_10CELLS-6.CNG.swc
# AZ_Adult2_10CELLS-7.CNG.swc
# AZ_Adult2_10CELLS-8.CNG.swc
# AZ_Adult2_10CELLS-9.CNG.swc
# AZ_Adult3_10CELLS-1.CNG.swc
# AZ_Adult3_10CELLS-10.CNG.swc
# AZ_Adult3_10CELLS-2.CNG.swc
# AZ_Adult3_10CELLS-3.CNG.swc
# AZ_Adult3_10CELLS-4.CNG.swc
# AZ_Adult3_10CELLS-5.CNG.swc
# AZ_Adult3_10CELLS-6.CNG.swc
# AZ_Adult3_10CELLS-7.CNG.swc
# AZ_Adult3_10CELLS-8.CNG.swc
# AZ_Adult3_10CELLS-9.CNG.swc
# AZ_Young1_10CELLS-1.CNG.swc
# AZ_Young1_10CELLS-10.CNG.swc
# AZ_Young1_10CELLS-2.CNG.swc
# AZ_Young1_10CELLS-3.CNG.swc
# AZ_Young1_10CELLS-4.CNG.swc
# AZ_Young1_10CELLS-5.CNG.swc
# AZ_Young1_10CELLS-6.CNG.swc
# AZ_Young1_10CELLS-7.CNG.swc
# AZ_Young1_10CELLS-8.CNG.swc
# AZ_Young1_10CELLS-9.CNG.swc
# AZ_Young2_10CELLS-1.CNG.swc
# AZ_Young2_10CELLS-10.CNG.swc
# AZ_Young2_10CELLS-2.CNG.swc
# AZ_Young2_10CELLS-3.CNG.swc
# AZ_Young2_10CELLS-4.CNG.swc
# AZ_Young2_10CELLS-5.CNG.swc
# AZ_Young2_10CELLS-6.CNG.swc
# AZ_Young2_10CELLS-7.CNG.swc
# AZ_Young2_10CELLS-8.CNG.swc
# AZ_Young2_10CELLS-9.CNG.swc
# AZ_Young3_10CELLS-1.CNG.swc
# AZ_Young3_10CELLS-10.CNG.swc
# AZ_Young3_10CELLS-2.CNG.swc
# AZ_Young3_10CELLS-3.CNG.swc
# AZ_Young3_10CELLS-4.CNG.swc
# AZ_Young3_10CELLS-5.CNG.swc
# AZ_Young3_10CELLS-6.CNG.swc
# AZ_Young3_10CELLS-7.CNG.swc
# AZ_Young3_10CELLS-8.CNG.swc
# AZ_Young3_10CELLS-9.CNG.swc
# PZ_Adult1-1.CNG.swc
# PZ_Adult1-10.CNG.swc
# PZ_Adult1-2.CNG.swc
# PZ_Adult1-3.CNG.swc
# PZ_Adult1-4.CNG.swc
# PZ_Adult1-5.CNG.swc
# PZ_Adult1-6.CNG.swc
# PZ_Adult1-7.CNG.swc
# PZ_Adult1-8.CNG.swc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-172d723d572c> in <module>
#      24     #try :
#      25
# ---> 26     tmp_var_dict = get_measurment(str(filename))
#      27
#      28     np.save(os.path.join(path,str(name +'_Lmeasurements.npy')),tmp_var_dict)
#
# <ipython-input-2-667dda04b670> in get_measurment(neuron)
#      45     features['HillmanThreshold']= getOneMeasure('HillmanThreshold',neuron)
#      46     features['Helix']= getOneMeasure('Helix',neuron)
# ---> 47     features['Fractal_Dim']= getOneMeasure('Fractal_Dim',neuron)
#      48
#      49     return features
#
# ~/miniconda3/envs/Optimisation/lib/python3.5/site-packages/pylmeasure/__init__.py in getOneMeasure(measure, swcFile, PCA, specificity)
#     516     :return: A dictionary with measure statistics
#     517     '''
# --> 518     result = getMeasure([measure], [swcFile], PCA=PCA, specificity=specificity)
#     519
#     520     return result[0]["WholeCellMeasuresDict"][0]
#
# ~/miniconda3/envs/Optimisation/lib/python3.5/site-packages/pylmeasure/__init__.py in getMeasure(measureNames, swcFileNames, PCA, specificity)
#     503
#     504     '''
# --> 505     return LMIOFunction('getMeasure', swcFileNames, measureNames, PCA=PCA, specificity=specificity)
#     506
#     507
#
# ~/miniconda3/envs/Optimisation/lib/python3.5/site-packages/pylmeasure/__init__.py in LMIOFunction(mode, swcFileNames, measure1Names, measure2Names, average, nBins, PCA, specificity)
#     480
#     481     with open(LMOutputFName, 'r') as outputFile:
# --> 482         lmOutput.readOutput(outputFile)
#     483
#     484     return lmOutput.LMOutput
#
# ~/miniconda3/envs/Optimisation/lib/python3.5/site-packages/pylmeasure/__init__.py in readOutput(self, outputFile)
#     342         for swcFileInd in range(self.lmInput.numberOfSWCFiles):
#     343             for measureInd in range(self.lmInput.numberOfMeasures):
# --> 344                 self.saveOneLine(measureInd, swcFileInd)
#     345
#     346     def readOneLine(self, start=0, end=None):
#
# ~/miniconda3/envs/Optimisation/lib/python3.5/site-packages/pylmeasure/__init__.py in saveOneLine(self, measureInd, swcFileInd)
#     375         line = self.readOneLine(2)
#     376
# --> 377         self.LMOutput[measureInd]['WholeCellMeasures'][swcFileInd, :] = line
#     378
#     379         # Parse the values from the line into corresponding dict keys
#
# ValueError: could not broadcast input array from shape (0) into shape (7)

# %%
np.save('blabla.npy',get_measurment('AZ_Adult1_10CELLS-10.CNG.swc'))

# %%
def get_measurment_full(neuron):
    
    features = dict()
    
    features['Surface'] = getOneMeasure('Surface',neuron)
    
    
    features['Soma_Surface'] = getOneMeasure('Soma_Surface',neuron)
    
    
    features['N_stems']= getOneMeasure('N_stems',neuron)
    
    
    features['N_bifs']= getOneMeasure('N_bifs',neuron)
    
    
    features['N_branch']= getOneMeasure('N_branch',neuron)
    
    
    features['N_tips']= getOneMeasure('N_tips',neuron)
    
    
    features['Width']= getOneMeasure('Width',neuron)
    
    
    features['Height']= getOneMeasure('Height',neuron)
    
    
    features['Depth']= getOneMeasure('Depth',neuron)
    
    
    features['Type']= getOneMeasure('Type',neuron)
    
    
    features['Diameter']= getOneMeasure('Diameter',neuron)
    
    
    features['Diameter_pow']= getOneMeasure('Diameter_pow',neuron)
    
    
    features['Length']= getOneMeasure('Length',neuron)
    
    
    features['Surface']= getOneMeasure('Surface',neuron)
    
    
    features['SectionArea']= getOneMeasure('SectionArea',neuron)
    
    
    features['Volume']= getOneMeasure('Volume',neuron)
    
    
    features['EucDistance']= getOneMeasure('EucDistance',neuron)
    
    
    features['PathDistance']= getOneMeasure('PathDistance',neuron)
    
    
    features['Branch_Order']= getOneMeasure('Branch_Order',neuron)
    
    
    features['Terminal_degree']= getOneMeasure('Terminal_degree',neuron)
    
    
    features['TerminalSegment']= getOneMeasure('TerminalSegment',neuron)
    
    
    features['Taper_1']= getOneMeasure('Taper_1',neuron)
    
    
    features['Taper_2']= getOneMeasure('Taper_2',neuron)
    
    
    features['Branch_pathlength']= getOneMeasure('Branch_pathlength',neuron)
    
    
    features['Contraction']= getOneMeasure('Contraction',neuron)
    
    
    features['Fragmentation']= getOneMeasure('Fragmentation',neuron)
    
    
    features['Daughter_Ratio']= getOneMeasure('Daughter_Ratio',neuron)
    
    
    features['Parent_Daughter_Ratio']= getOneMeasure('Parent_Daughter_Ratio',neuron)
    
    
    features['Partition_asymmetry']= getOneMeasure('Partition_asymmetry',neuron)
    
    
    features['Rall_Power']= getOneMeasure('Rall_Power',neuron)
    
    
    features['Pk']= getOneMeasure('Pk',neuron)
    
    
    features['Pk_classic']= getOneMeasure('Pk_classic',neuron)
    
    
    features['Pk_2']= getOneMeasure('Pk_2',neuron)
    
    
    features['Bif_ampl_local']= getOneMeasure('Bif_ampl_local',neuron)
    
    
    features['Bif_ampl_remote']= getOneMeasure('Bif_ampl_remote',neuron)
    
    
    features['Bif_tilt_local']= getOneMeasure('Bif_tilt_local',neuron)
    
    
    features['Bif_tilt_remote']= getOneMeasure('Bif_tilt_remote',neuron)
    
    
    features['Bif_torque_local']= getOneMeasure('Bif_torque_local',neuron)
    
    
    features['Bif_torque_remote']= getOneMeasure('Bif_torque_remote',neuron)
    
    
    features['Last_parent_diam']= getOneMeasure('Last_parent_diam',neuron)
    
    
    features['Diam_threshold']= getOneMeasure('Diam_threshold',neuron)
    
    
    features['HillmanThreshold']= getOneMeasure('HillmanThreshold',neuron)
    
    
    features['Helix']= getOneMeasure('Helix',neuron)
    
    
    features['Fractal_Dim']= getOneMeasure('Fractal_Dim',neuron)
    
    return features
